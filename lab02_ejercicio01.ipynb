# %% [markdown]
# <a href="https://colab.research.google.com/github/danicardenas26/LAB-Python-02/blob/main/lab02_ejercicio01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# a. Crear una lambda que reciba un número y devuelva True si es múltiplo de 3, False en caso contrario.
es_multiplo_de_3 = lambda x: x % 3 == 0

# b. Crear una lambda que reciba un número y devuelva su cubo.
cubo = lambda x: x ** 3

# c. Crear una lambda que reciba dos números y devuelva su producto.
producto = lambda x, y: x * y

# d. Crear una lambda que reciba dos números y devuelva el mayor.
mayor = lambda x, y: x if x > y else y

# e. Crear una lambda que reciba una palabra y devuelva True si empieza con la letra "A" (o "a").
empieza_con_a = lambda palabra: palabra[0].lower() == 'a' if len(palabra) > 0 else False

# f. Crear una lambda que reciba una temperatura en Celsius y la convierta a Fahrenheit.
celsius_a_fahrenheit = lambda c: (c * 9/5) + 32

# %%
# 1. Crear una lista que contenga tres lambdas:
lambdas_lista = [
    lambda x: x * 2,
    lambda x: x + 10,
    lambda x: x ** 2
]

# 2. Pedir un número al usuario
numero_ingresado = int(input("Ingrese un número: "))

# 3. Aplicar cada lambda a ese número, mostrando los resultados
for funcion in lambdas_lista:
    resultado = funcion(numero_ingresado)
    print(resultado)
# Out:
# Ingrese un número: 5
# 10
# 15
# 25
